# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Solicitud de datos al usuario #
ticker = input(['Ingrese el símbolo de la acción: '])
yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open       Volume
# Ticker     0P0000X4KI.F 0P0000X4KI.F 0P0000X4KI.F 0P0000X4KI.F 0P0000X4KI.F
# Date
# 2026-08-04      4.00783      4.00783      4.00783      4.00783            0
# 2026-08-05      4.00643      4.00643      4.00643      4.00643            0
# 2026-08-06      3.99305      3.99305      3.99305      3.99305            0
# 2026-08-07      4.01909      4.01909      4.01909      4.01909            0
# 2026-08-10      4.04313      4.04313      4.04313      4.04313            0
# 2026-08-11      4.03567      4.03567      4.03567      4.03567            0
# 2026-08-12      4.05614      4.05614      4.05614      4.05614            0
# 2026-08-13      4.08449      4.08449      4.08449      4.08449            0
# 2026-08-14      4.04967      4.04967      4.04967      4.04967            0
# 2026-08-17      4.03284      4.03284      4.03284      4.03284            0
# 2026-08-18      3.96760      3.96760      3.96760      3.96760            0
# 2026-08-19      3.92477      3.92477      3.92477      3.92477            0
# 2026-08-20      3.88152      3.88152      3.88152      3.88152            0
# 2026-08-21      3.91116      3.91116      3.91116      3.91116            0
# 2026-08-24      3.89894      3.89894      3.89894      3.89894            0
# 2026-08-25      3.92292      3.92292      3.92292      3.92292            0
# 2026-08-26      3.92562      3.92562      3.92562      3.92562            0
# 2026-08-27      3.98103      3.98103      3.98103      3.98103            0
# 2026-08-28      3.98465      3.98465      3.98465      3.98465            0
# 2026-08-31      3.95486      3.95486      3.95486      3.95486            0
# 2026-09-01      3.89617      3.89617      3.89617      3.89617            0
# 2026-09-02      3.85926      3.85926      3.85926      3.85926            0
# 2026-09-03      3.91960      3.91960      3.91960      3.91960            0

# %%
data_ticker = yf.download(ticker)
dt_start = input(['Ingrese la fecha de inicio (YYYY-MM-DD): '])
dt_end = input(['Ingrese la fecha de fin (YYYY-MM-DD): '])
data = yf.Ticker(ticker)
table = data.history(start=dt_start, end=dt_end)
table
# Out:
# [*********************100%***********************]  1 of 1 completed
#                               Open     High      Low    Close  Volume  \
# Date
# 2026-03-09 00:00:00+01:00  3.41843  3.41843  3.41843  3.41843       0
# 2026-03-10 00:00:00+01:00  3.45356  3.45356  3.45356  3.45356       0
# 2026-03-11 00:00:00+01:00  3.44922  3.44922  3.44922  3.44922       0
# 2026-03-12 00:00:00+01:00  3.42298  3.42298  3.42298  3.42298       0
# 2026-03-13 00:00:00+01:00  3.42551  3.42551  3.42551  3.42551       0
# ...                            ...      ...      ...      ...     ...
# 2026-08-28 00:00:00+02:00  3.98465  3.98465  3.98465  3.98465       0
# 2026-08-31 00:00:00+02:00  3.95486  3.95486  3.95486  3.95486       0
# 2026-09-01 00:00:00+02:00  3.89617  3.89617  3.89617  3.89617       0
# 2026-09-02 00:00:00+02:00  3.85926  3.85926  3.85926  3.85926       0
# 2026-09-03 00:00:00+02:00  3.91960  3.91960  3.91960  3.91960       0
#
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2026-03-09 00:00:00+01:00        0.0           0.0            0.0
# 2026-03-10 00:00:00+01:00        0.0           0.0            0.0
# 2026-03-11 00:00:00+01:00        0.0           0.0            0.0
# 2026-03-12 00:00:00+01:00        0.0           0.0            0.0
# 2026-03-13 00:00:00+01:00        0.0           0.0            0.0
# ...                              ...           ...            ...
# 2026-08-28 00:00:00+02:00        0.0           0.0            0.0
# 2026-08-31 00:00:00+02:00        0.0           0.0            0.0
# 2026-09-01 00:00:00+02:00        0.0           0.0            0.0
# 2026-09-02 00:00:00+02:00        0.0           0.0            0.0
# 2026-09-03 00:00:00+02:00        0.0           0.0            0.0
#
# [126 rows x 8 columns]

# %%
close_table = table.Close
close_table
# Out:
# Date
# 2026-03-09 00:00:00+01:00    3.41843
# 2026-03-10 00:00:00+01:00    3.45356
# 2026-03-11 00:00:00+01:00    3.44922
# 2026-03-12 00:00:00+01:00    3.42298
# 2026-03-13 00:00:00+01:00    3.42551
#                               ...
# 2026-08-28 00:00:00+02:00    3.98465
# 2026-08-31 00:00:00+02:00    3.95486
# 2026-09-01 00:00:00+02:00    3.89617
# 2026-09-02 00:00:00+02:00    3.85926
# 2026-09-03 00:00:00+02:00    3.91960
# Name: Close, Length: 126, dtype: float64

# %%
close_table.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
maximum = round(close_table.max(), 2)
minimum = round(close_table.min(), 2)
value_mean = round(close_table.mean(), 2)

print(f'El valor máximo de {ticker} es: {maximum}', end=' * ')
print(f'El valor mínimo de {ticker} es: {minimum}', end=' | ')
print(f'El valor promedio de {ticker} es: {value_mean}')
# Out:
# El valor máximo de 0P0000X4KI.F es: 4.08 * El valor mínimo de 0P0000X4KI.F es: 3.23 | El valor promedio de 0P0000X4KI.F es: 3.74

# %%
import time as t
# !pip3 install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyobjc-core (from pyautogui)
#   Downloading pyobjc_core-12.2.2-cp314-cp314-macosx_10_15_universal2.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-quartz (from pyautogui)
#   Downloading pyobjc_framework_quartz-12.2.2-cp314-cp314-macosx_10_15_universal2.whl.metadata (3.6 kB)
# Collecting pymsgbox (from pyautogui)
#   Downloading pymsgbox-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting pytweening>=1.0.4 (from pyautogui)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyscreeze>=0.1.21 (from pyautogui)
#   Downloading pyscreeze-1.0.1.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygetwindow>=0.0.5 (from pyautogui)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mouseinfo (from pyautogui)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rubicon-objc (from mouseinfo->pyautogui)
#   Downloading rubicon_objc-0.5.6-py3-none-any.whl.metadata (4.4 kB)
# Collecting pyperclip (from mouseinfo->pyautogui)
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Cocoa>=12.2.2 (from pyobjc-framework-quartz->pyautogui)
#   Downloading pyobjc_framework_cocoa-12.2.2-cp314-cp314-macosx_10_15_universal2.whl.metadata (2.6 kB)
# Downloading pymsgbox-2.0.1-py3-none-any.whl (10.0 kB)
# Downloading pyobjc_core-12.2.2-cp314-cp314-macosx_10_15_universal2.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 31.1 MB/s  0:00:00 eta 0:00:01
# Downloading pyobjc_framework_quartz-12.2.2-cp314-cp314-macosx_10_15_universal2.whl (219 kB)
# Downloading pyobjc_framework_cocoa-12.2.2-cp314-cp314-macosx_10_15_universal2.whl (388 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Downloading rubicon_objc-0.5.6-py3-none-any.whl (66 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, pytweening, mouseinfo, pyrect
#   Building wheel for pyautogui (pyproject.toml) ... done
#   Created wheel for pyautogui: filename=pyautogui-0.9.54-py3-none-any.whl size=37684 sha256=973ddf9d74f1deeae07bdd91b2577535c4bf430b72efc24a561a6796fcda00b7
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/ca/b4/95/cf5a29a851ace0775449ac396a9b57079fd79d83c590721721
#   Building wheel for pygetwindow (pyproject.toml) ... done
#   Created wheel for pygetwindow: filename=pygetwindow-0.0.9-py3-none-any.whl size=11120 sha256=b4fa3fa19b4a3558d64e23d8b12aac16bae0792402037065d50ffcc747d4b062
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/bb/fd/26/07b121e630055203efa057fb954dba169e133d1645490148d4
#   Building wheel for pyscreeze (pyproject.toml) ... done
#   Created wheel for pyscreeze: filename=pyscreeze-1.0.1-py3-none-any.whl size=14458 sha256=ad31feb3aa0c888075072325aa6b651d5086e902e2cedfbce481787b70935e0f
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/b1/ca/37/919891db591fa39a08cdbf3e63b10eb7125a4db469df5d8842
#   Building wheel for pytweening (pyproject.toml) ... done
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8113 sha256=35511a6d35be84a0f0d9212165b58178414396dedf4bd655f3aa759bace8c3c0
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/c6/78/9a/cf4cd54e05aef6b372f6726b1f2b44c59cfedfc034e6604811
#   Building wheel for mouseinfo (pyproject.toml) ... done
#   Created wheel for mouseinfo: filename=mouseinfo-0.1.3-py3-none-any.whl size=10943 sha256=02e51334de0a40a3607c495b7878eca4df311676d349c81b645bf518b602a402
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/bc/17/24/3c0fec948238390529495ca83b644f82486960fb38ca23a3a7
#   Building wheel for pyrect (pyproject.toml) ... done
#   Created wheel for pyrect: filename=pyrect-0.2.0-py2.py3-none-any.whl size=11278 sha256=10421a0acc6e086fc4449794461c5f400d6dd1ee52aa5fa3bb9d6f5b8e7d28cd
#   Stored in directory: /Users/gdzpaolo/Library/Caches/pip/wheels/b6/11/ea/b71b99776a917d87627d208da4d496ad361df7db41b0dd1b34
# Successfully built pyautogui pygetwindow pyscreeze pytweening mouseinfo pyrect
# Installing collected packages: pytweening, pyscreeze, pyrect, pyperclip, rubicon-objc, pyobjc-core, pymsgbox, pygetwindow, pyobjc-framework-Cocoa, mouseinfo, pyobjc-framework-quartz, pyautogui
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [pyautogui]12 [pyobjc-framework-Cocoa]
# Successfully installed mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-2.0.1 pyobjc-core-12.2.2 pyobjc-framework-Cocoa-12.2.2 pyobjc-framework-quartz-12.2.2 pyperclip-1.11.0 pyrect-0.2.0 pyscreeze-1.0.1 pytweening-1.2.0 rubicon-objc-0.5.6
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
